# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
from sklearn.model_selection import train_test_split
from sklearn.linear_model import Lasso, Ridge
from sklearn.ensemble import RandomForestRegressor as RF
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import mean_squared_error as MSE, r2_score as r2
from sklearn.preprocessing import MinMaxScaler
from sklearn.cluster import AgglomerativeClustering
from sklearn.cluster import KMeans
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import StandardScaler

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'svg'

# %% [markdown]
# <H1>Работа с обучающим датасетом</H1>

# %%
df=pd.read_csv('train.csv')

# %%
data=df.copy()

# %% [markdown]
# <h2>Предобработка данных</h2>

# %%
data = data.drop(['Healthcare_1'], axis = 1)

# %%
data = pd.get_dummies(data)

# %% [markdown]
# <H3> Год строительства </H3>

# %% [markdown]
# Исправление ошибок в данных

# %%
data.loc[data['HouseYear'] > 2021]
# Out:
#          Id  DistrictId  Rooms     Square  LifeSquare  KitchenSquare  Floor  \
# 1497  10814         109    1.0  37.265070   20.239714            9.0      9
# 4189  11607         147    2.0  44.791836   28.360393            5.0      4
#
#       HouseFloor  HouseYear  Ecology_1  ...  Social_3  Helthcare_2  Shops_1  \
# 1497        12.0   20052011   0.136330  ...        10            3        6
# 4189         9.0       4968   0.319809  ...        16            5        8
#
#               Price  Ecology_2_A  Ecology_2_B  Ecology_3_A  Ecology_3_B  \
# 1497  254084.534396            0            1            0            1
# 4189  243028.603096            0            1            0            1
#
#       Shops_2_A  Shops_2_B
# 1497          0          1
# 4189          0          1
#
# [2 rows x 22 columns]

# %%
data.loc[data.HouseYear == 20052011,'HouseYear'] = 2011

# %%
data.loc[data.HouseYear == 4968,'HouseYear'] = 1968

# %% [markdown]
# Новый признак: время застройки района

# %%
dist_mean_year = data.groupby(['DistrictId'])[['HouseYear']].mean().astype('int32').reset_index().rename(columns = {'HouseYear': 'Dist_mean_year'})
data = data.merge(dist_mean_year, on = ('DistrictId'), how ='left')

# %% [markdown]
# Новый признак: новостройка

# %%
data['New_House'] = (data['HouseYear'] >= 2018).astype('int32')

# %% [markdown]
# <H3> Площадь </H3>

# %% [markdown]
# Исправление ошибок в данных

# %%
data.loc[data.Rooms>5]
# Out:
#          Id  DistrictId  Rooms     Square  LifeSquare  KitchenSquare  Floor  \
# 377    5927          57   10.0  59.056975   36.223072           10.0     22
# 1454   8491           1   19.0  42.006046   21.779288            7.0     17
# 2170  14003          99    6.0  59.414334   38.702244            6.0      7
# 8849  14865           9   10.0  60.871266   38.420681           10.0      3
#
#       HouseFloor  HouseYear  Ecology_1  ...  Shops_1          Price  \
# 377         22.0       2002   0.090799  ...       15  317265.323792
# 1454        17.0       2014   0.007122  ...        1   78364.616704
# 2170         9.0       1969   0.033494  ...        8  229661.964416
# 8849         2.0       1994   0.161532  ...        4  172329.270863
#
#       Ecology_2_A  Ecology_2_B  Ecology_3_A  Ecology_3_B  Shops_2_A  \
# 377             0            1            0            1          0
# 1454            0            1            0            1          0
# 2170            0            1            0            1          0
# 8849            0            1            0            1          0
#
#       Shops_2_B  Dist_mean_year  New_House
# 377           1            1989          0
# 1454          1            1985          0
# 2170          1            1976          0
# 8849          1            1988          0
#
# [4 rows x 24 columns]

# %%
data.loc[1454,'Rooms'] = 1

# %%
data.loc[[377,2170,8849],'Rooms'] = 2

# %%
data.loc[data.Rooms == 0]
# Out:
#          Id  DistrictId  Rooms      Square  LifeSquare  KitchenSquare  Floor  \
# 1397  12638          27    0.0  138.427694  136.215499            0.0      4
# 1981   7917          27    0.0  212.932361  211.231125            0.0      2
# 2269   7317          27    0.0   41.790881         NaN            0.0     13
# 3911    770          28    0.0   49.483501         NaN            0.0     16
# 4366    456           6    0.0   81.491446         NaN            0.0      4
# 4853   3224          27    0.0    2.377248    0.873147            0.0      1
# 6149   3159          88    0.0   38.697117   19.345131            9.0      9
# 8834   9443          27    0.0   87.762616   85.125471            0.0      5
#
#       HouseFloor  HouseYear  Ecology_1  ...  Shops_1          Price  \
# 1397         3.0       2016   0.075424  ...        0  268394.744389
# 1981         3.0       2008   0.211401  ...        1  302211.260887
# 2269         0.0       1977   0.211401  ...        1   98129.976788
# 3911         0.0       2015   0.118537  ...        0  217009.338463
# 4366         0.0       1977   0.243205  ...        0  212864.799112
# 4853         0.0       1977   0.017647  ...        0  126596.941798
# 6149        16.0       1982   0.127376  ...        9  158998.110646
# 8834        15.0       1977   0.211401  ...        1  219281.918007
#
#       Ecology_2_A  Ecology_2_B  Ecology_3_A  Ecology_3_B  Shops_2_A  \
# 1397            0            1            0            1          0
# 1981            0            1            0            1          0
# 2269            0            1            0            1          0
# 3911            0            1            0            1          0
# 4366            0            1            0            1          0
# 4853            0            1            0            1          0
# 6149            0            1            0            1          0
# 8834            0            1            0            1          0
#
#       Shops_2_B  Dist_mean_year  New_House
# 1397          1            1994          0
# 1981          1            1994          0
# 2269          1            1994          0
# 3911          1            1981          0
# 4366          1            1990          0
# 4853          1            1994          0
# 6149          1            1982          0
# 8834          1            1994          0
#
# [8 rows x 24 columns]

# %%
data.loc[[1397,1981],'Rooms'] = 4
data.loc[[8834],'Rooms'] = 3
data.loc[[4366],'Rooms'] = 2
data.loc[[2269, 3911, 6149],'Rooms'] = 1

# %%
data.loc[data.Rooms == 0]
# Out:
#         Id  DistrictId  Rooms    Square  LifeSquare  KitchenSquare  Floor  \
# 4853  3224          27    0.0  2.377248    0.873147            0.0      1
#
#       HouseFloor  HouseYear  Ecology_1  ...  Shops_1          Price  \
# 4853         0.0       1977   0.017647  ...        0  126596.941798
#
#       Ecology_2_A  Ecology_2_B  Ecology_3_A  Ecology_3_B  Shops_2_A  \
# 4853            0            1            0            1          0
#
#       Shops_2_B  Dist_mean_year  New_House
# 4853          1            1994          0
#
# [1 rows x 24 columns]

# %%
data.drop(4853, inplace=True)

# %%
data.loc[data.LifeSquare>200]
# Out:
#          Id  DistrictId  Rooms      Square   LifeSquare  KitchenSquare  Floor  \
# 590   14990          23    2.0   48.449873   263.542020            5.0      6
# 1981   7917          27    4.0  212.932361   211.231125            0.0      2
# 1982   5548          86    5.0  275.645284   233.949309           26.0     12
# 4328  16550          27    3.0   81.694417  7480.592129            1.0      9
# 4690   2307         102    1.0  409.425181   410.639749           10.0      4
# 6977  11602          30    2.0  641.065193   638.163193           10.0     20
# 8437  15886          85    3.0   78.059331   461.463614           10.0     12
# 9910  16568          27    4.0  200.334539   201.627361           25.0      1
#
#       HouseFloor  HouseYear  Ecology_1  ...  Shops_1          Price  \
# 590          5.0       1972   0.075779  ...        2  141780.231857
# 1981         3.0       2008   0.211401  ...        1  302211.260887
# 1982        37.0       2011   0.161976  ...        7  455264.882666
# 4328        17.0       2016   0.017647  ...        0  217357.492366
# 4690         4.0       2016   0.238617  ...        6   90470.430830
# 6977        19.0       2019   0.000078  ...       23  133529.681562
# 8437        16.0       1998   0.037178  ...        7  394253.299978
# 9910         2.0       2013   0.041116  ...        4  528560.506016
#
#       Ecology_2_A  Ecology_2_B  Ecology_3_A  Ecology_3_B  Shops_2_A  \
# 590             0            1            0            1          0
# 1981            0            1            0            1          0
# 1982            0            1            1            0          0
# 4328            0            1            0            1          0
# 4690            0            1            0            1          0
# 6977            0            1            0            1          0
# 8437            0            1            0            1          0
# 9910            0            1            0            1          0
#
#       Shops_2_B  Dist_mean_year  New_House
# 590           1            1987          0
# 1981          1            1994          0
# 1982          1            1975          0
# 4328          1            1994          0
# 4690          1            1985          0
# 6977          1            1992          1
# 8437          1            1980          0
# 9910          1            1994          0
#
# [8 rows x 24 columns]

# %%
data.drop(data[data.LifeSquare > 300].index, inplace=True)

# %%
data.loc[(data.LifeSquare - data.Square > 5)]
# Out:
#          Id  DistrictId  Rooms     Square  LifeSquare  KitchenSquare  Floor  \
# 212    1748          88    2.0   5.497061   67.628717            1.0     24
# 590   14990          23    2.0  48.449873  263.542020            5.0      6
# 3280  10527          27    1.0   4.380726   40.805837            1.0     10
# 4638   4071           6    3.0  75.203314   82.486992            1.0     13
# 6332   8961          27    1.0  33.398983  164.153360            6.0      3
# 8030  13265           1    3.0   4.823679   79.767964            0.0      6
#
#       HouseFloor  HouseYear  Ecology_1  ...  Shops_1          Price  \
# 212         22.0       1977   0.127376  ...        9  412511.088764
# 590          5.0       1972   0.075779  ...        2  141780.231857
# 3280        17.0       2013   0.211401  ...        1   97560.720383
# 4638        25.0       2015   0.243205  ...        0  211324.917957
# 6332         5.0       1965   0.211401  ...        1  104891.073757
# 8030        17.0       1977   0.007122  ...        1  237716.681261
#
#       Ecology_2_A  Ecology_2_B  Ecology_3_A  Ecology_3_B  Shops_2_A  \
# 212             0            1            0            1          0
# 590             0            1            0            1          0
# 3280            0            1            0            1          0
# 4638            0            1            0            1          0
# 6332            0            1            0            1          0
# 8030            0            1            0            1          0
#
#       Shops_2_B  Dist_mean_year  New_House
# 212           1            1982          0
# 590           1            1987          0
# 3280          1            1994          0
# 4638          1            1990          0
# 6332          1            1994          0
# 8030          1            1985          0
#
# [6 rows x 24 columns]

# %%
data.loc[[590],'LifeSquare']=26.354
data.loc[[3280],'Square']=43.807
data.loc[[6332],'LifeSquare']=16.415

# %%
data.drop(data[data.LifeSquare - data.Square > 5].index, inplace=True)

# %%
data.loc[(data.Square<15)|(data.Square>300)]
# Out:
#          Id  DistrictId  Rooms      Square  LifeSquare  KitchenSquare  Floor  \
# 1316  11526          27    1.0    4.633498    1.969969            1.0     18
# 1608  10202           6    1.0    2.596351    4.604943            1.0      3
# 3413   9487           5    1.0    5.129222    5.549458            1.0      1
# 4262     28           9    2.0  604.705972         NaN            1.0     17
# 4739  12676          81    3.0   13.784865   15.988889            7.0      4
# 4900   4504          27    3.0    4.390331    5.610772            1.0      8
# 6392  14786           1    1.0    1.136859    4.525736            1.0      3
# 8283  15744          34    1.0    1.988943    2.642219            1.0     21
# 9294   6782          45    1.0    2.954309    5.257278            1.0      3
# 9613   7657          38    1.0    4.502784    4.618547            1.0     28
#
#       HouseFloor  HouseYear  Ecology_1  ...  Shops_1          Price  \
# 1316         1.0       1977   0.011654  ...        0  107604.269441
# 1608        25.0       2014   0.243205  ...        0  137597.601458
# 3413         1.0       1977   0.150818  ...        5  369472.403061
# 4262        18.0       1977   0.161532  ...        4  187717.242538
# 4739         5.0       1960   0.319809  ...        8   78388.806186
# 4900        19.0       2016   0.211401  ...        1  161379.067034
# 6392         1.0       1977   0.007122  ...        1  181434.825589
# 8283         4.0       1977   0.069753  ...       11  458378.777006
# 9294         1.0       1977   0.195781  ...        2  438005.182323
# 9613         1.0       1977   0.060753  ...        7  483283.488083
#
#       Ecology_2_A  Ecology_2_B  Ecology_3_A  Ecology_3_B  Shops_2_A  \
# 1316            0            1            0            1          0
# 1608            0            1            0            1          0
# 3413            0            1            0            1          0
# 4262            0            1            0            1          0
# 4739            0            1            0            1          0
# 4900            0            1            0            1          0
# 6392            0            1            0            1          0
# 8283            0            1            0            1          0
# 9294            0            1            0            1          0
# 9613            0            1            0            1          0
#
#       Shops_2_B  Dist_mean_year  New_House
# 1316          1            1994          0
# 1608          1            1990          0
# 3413          1            1979          0
# 4262          1            1988          0
# 4739          1            1972          0
# 4900          1            1994          0
# 6392          1            1985          0
# 8283          1            2002          0
# 9294          1            1988          0
# 9613          1            2000          0
#
# [10 rows x 24 columns]

# %%
data.loc[[1316],'Square']=46.334
data.loc[[1608],'Square']=25.963
data.loc[[4262],'Square']=60.705
data.loc[[4900],'Square']=43.903

data.drop(3414, inplace=True)
data.drop(6392, inplace=True)
data.drop(8283, inplace=True)
data.drop(9294, inplace=True)
data.drop(9613, inplace=True)

# %%
data.loc[(data.Square<15)]
# Out:
#          Id  DistrictId  Rooms     Square  LifeSquare  KitchenSquare  Floor  \
# 3413   9487           5    1.0   5.129222    5.549458            1.0      1
# 4739  12676          81    3.0  13.784865   15.988889            7.0      4
#
#       HouseFloor  HouseYear  Ecology_1  ...  Shops_1          Price  \
# 3413         1.0       1977   0.150818  ...        5  369472.403061
# 4739         5.0       1960   0.319809  ...        8   78388.806186
#
#       Ecology_2_A  Ecology_2_B  Ecology_3_A  Ecology_3_B  Shops_2_A  \
# 3413            0            1            0            1          0
# 4739            0            1            0            1          0
#
#       Shops_2_B  Dist_mean_year  New_House
# 3413          1            1979          0
# 4739          1            1972          0
#
# [2 rows x 24 columns]

# %%
data.drop(3413, inplace=True)
data.drop(4739, inplace=True)

# %%
# square_lifesquare=(data.Square/data.LifeSquare).mean()
# square_lifesquare

# %%
# def fillna_lifesquare(df, df_source):
#     df['LifeSquare']=df['LifeSquare'].fillna(df_source['Square']/square_lifesquare)
#     return df

# %% [markdown]
# <H3>Этажность</H3>

# %% [markdown]
# Исправление ошибок

# %%
data.loc[data.Floor>data.HouseFloor,'HouseFloor']=data.loc[data.Floor>data.HouseFloor,'Floor']

# %% [markdown]
# Новый признак: первый и последний этаж

# %%
data['frs_lst_floor'] = (data['Floor'] == data['HouseFloor']) | (data['Floor'] <= 1)
data['frs_lst_floor'] = data['frs_lst_floor'].astype('int')

# %% [markdown]
# <H2>Обучение </H2>

# %% [markdown]
# Определение факторов для построения модели

# %%
data.columns
# Out:
# Index(['Id', 'DistrictId', 'Rooms', 'Square', 'LifeSquare', 'KitchenSquare',
#        'Floor', 'HouseFloor', 'HouseYear', 'Ecology_1', 'Social_1', 'Social_2',
#        'Social_3', 'Helthcare_2', 'Shops_1', 'Price', 'Ecology_2_A',
#        'Ecology_2_B', 'Ecology_3_A', 'Ecology_3_B', 'Shops_2_A', 'Shops_2_B',
#        'Dist_mean_year', 'New_House', 'frs_lst_floor'],
#       dtype='object')

# %%
features = [
#     'Id', 
    'DistrictId', 
#     'Rooms', 
    'Square', 
#     'LifeSquare', 
#     'KitchenSquare',
    'Floor', 
    'HouseFloor', 
    'HouseYear', 
    'Ecology_1', 
    'Social_1', 
    'Social_2',
    'Social_3', 
    'Helthcare_2', 
    'Shops_1', 
#     'Price', 
    'Ecology_2_A',
    'Ecology_2_B',
    'Ecology_3_A', 
    'Ecology_3_B', 
    'Shops_2_A', 
    'Shops_2_B',
    'Dist_mean_year', 
    'New_House', 
    'frs_lst_floor']

# %% [markdown]
# Формирование наборов данных

# %%
X = data[features]

# %%
y = data['Price']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %% [markdown]
# Нормализация данных

# %%
scaler = StandardScaler()

# %%
X_train_scaled = scaler.fit_transform(X_train)

# %%
X_test_scaled = scaler.transform(X_test)

# %%
X_train_scaled = pd.DataFrame(X_train_scaled, columns = features)

# %%
X_test_scaled = pd.DataFrame(X_test_scaled, columns = features)

# %% [markdown]
# Обучение модели

# %%
model = RF(n_estimators = 2000,  max_depth = 8, random_state = 42, n_jobs = 8)

# %%
model.fit(X_train_scaled, y_train)
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=8,
#            max_features='auto', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators=2000, n_jobs=8,
#            oob_score=False, random_state=42, verbose=0, warm_start=False)

# %%
pred_train = model.predict(X_train_scaled)

# %%
r2(y_train, pred_train)
# Out:
# 0.79455403349488

# %% [markdown]
# Проверка

# %%
pred_test = model.predict(X_test_scaled)

# %%
r2(y_test, pred_test)
# Out:
# 0.7253076007903596

# %% [markdown]
# Подбор параметров модели

# %%
score_train = 0
score_test = 0
best_dep = 0
for i in range(100, 2000, 100):
        model = RF(n_estimators = i,  max_depth = 15, random_state = 42, n_jobs = 8)
        model.fit(X_train, y_train)
        pred_train = model.predict(X_train)
        r2_train = r2(y_train, pred_train)
        pred_test = model.predict(X_test)
        r2_test = r2(y_test, pred_test)
        if r2_test > score_test:
                score_test = r2_test
                score_train = r2_train
                best_dep = i
print(score_test, best_dep, score_train)
# Out:
# 0.7495526271439328 1600 0.9419684107945676

# %%
model = RF(n_estimators = 1600,  max_depth = 15, random_state = 42, n_jobs = 8)

# %%
model.fit(X_train, y_train)
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=15,
#            max_features='auto', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators=1600, n_jobs=8,
#            oob_score=False, random_state=42, verbose=0, warm_start=False)

# %%
pred_train = model.predict(X_train)

# %%
r2_train = r2(y_train, pred_train)

# %%
pred_test = model.predict(X_test)

# %%
r2_test = r2(y_test, pred_test)

# %%
print(r2_test)
# Out:
# 0.7495526271439328

# %% [markdown]
# <H1>Работа с тестовым датасетом</H1>

# %%
ts = pd.read_csv('test.csv')

# %%
test = ts.copy()

# %% [markdown]
# <h2>Предобработка данных</h2>

# %%
test = test.drop(['Healthcare_1'], axis = 1)

# %%
test = pd.get_dummies(test)

# %% [markdown]
# Исправление ошибок в данных

# %%
test.loc[test['HouseYear']].describe()
# Out:
#                  Id   DistrictId       Rooms       Square   LifeSquare  \
# count   5000.000000  5000.000000  5000.00000  5000.000000  4311.000000
# mean   10284.873600    59.318600     1.63640    52.489499    32.196843
# std     4959.119702    40.749621     0.72519    20.619943    16.425226
# min      164.000000     0.000000     1.00000    29.708662     2.712936
# 25%     5439.000000    27.000000     1.00000    35.124873    21.465834
# 50%    11253.000000    58.000000     1.00000    45.596795    27.662295
# 75%    14863.000000    74.000000     2.00000    61.646444    38.905038
# max    16792.000000   184.000000     4.00000   125.538178   126.473035
#
#        KitchenSquare        Floor   HouseFloor    HouseYear    Ecology_1  ...  \
# count    5000.000000  5000.000000  5000.000000  5000.000000  5000.000000  ...
# mean       14.710600     7.378800    12.319000  1985.566400     0.210495  ...
# std        70.647652     4.579859     5.345667    17.860442     0.171325  ...
# min         0.000000     1.000000     0.000000  1953.000000     0.000000  ...
# 25%         5.000000     4.000000     9.000000  1976.000000     0.041125  ...
# 50%         6.000000     6.000000    12.000000  1981.000000     0.174739  ...
# 75%         9.000000    10.000000    16.000000  2002.000000     0.437885  ...
# max       620.000000    26.000000    26.000000  2019.000000     0.437885  ...
#
#            Social_2     Social_3  Helthcare_2      Shops_1  Ecology_2_A  \
# count   5000.000000  5000.000000  5000.000000  5000.000000  5000.000000
# mean    5631.666600     6.308600     1.298400     4.472000     0.017600
# std     3216.781265    18.299069     1.637282     3.813781     0.131506
# min      168.000000     0.000000     0.000000     0.000000     0.000000
# 25%     3893.000000     1.000000     0.000000     1.000000     0.000000
# 50%     5735.000000     3.000000     0.500000     5.000000     0.000000
# 75%     6564.000000     4.000000     3.000000     5.000000     0.000000
# max    19083.000000   141.000000     6.000000    23.000000     1.000000
#
#        Ecology_2_B  Ecology_3_A  Ecology_3_B    Shops_2_A    Shops_2_B
# count  5000.000000  5000.000000  5000.000000  5000.000000  5000.000000
# mean      0.982400     0.033400     0.966600     0.068000     0.932000
# std       0.131506     0.179697     0.179697     0.251771     0.251771
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       1.000000     0.000000     1.000000     0.000000     1.000000
# 50%       1.000000     0.000000     1.000000     0.000000     1.000000
# 75%       1.000000     0.000000     1.000000     0.000000     1.000000
# max       1.000000     1.000000     1.000000     1.000000     1.000000
#
# [8 rows x 21 columns]

# %%
test['HouseYear'].describe()
# Out:
# count    5000.000000
# mean     1984.392600
# std        18.573149
# min      1908.000000
# 25%      1973.000000
# 50%      1977.000000
# 75%      2000.000000
# max      2020.000000
# Name: HouseYear, dtype: float64

# %% [markdown]
# Новый признак: время застройки района

# %% [markdown]
# <H3> Год строительства </H3>

# %%
dist_mean_year = test.groupby(['DistrictId'])[['HouseYear']].mean().astype('int32').reset_index().rename(columns = {'HouseYear': 'Dist_mean_year'})
test = test.merge(dist_mean_year, on = ('DistrictId'), how ='left')

# %% [markdown]
# Новый признак: новостройка

# %%
test['New_House'] = (test['HouseYear'] >= 2018).astype('int32')

# %% [markdown]
# <H3> Площадь </H3>

# %% [markdown]
# Исправление ошибок в данных

# %%
test.loc[data.Rooms].describe()
# Out:
#                  Id   DistrictId        Rooms       Square   LifeSquare  \
# count   9985.000000  9985.000000  9985.000000  9985.000000  6264.000000
# mean   11740.214522   112.315473     1.594191    48.083978    29.427535
# std     5008.785501    62.936643     0.491072    27.714198    17.257342
# min     5480.000000    27.000000     1.000000    13.597819    15.948246
# 25%     5480.000000    74.000000     1.000000    13.597819    15.948246
# 50%    15664.000000    74.000000     2.000000    69.263183    15.948246
# 75%    15856.000000   190.000000     2.000000    69.263183    51.940842
# max    15856.000000   190.000000     2.000000    73.046609    51.940842
#
#        KitchenSquare        Floor   HouseFloor    HouseYear    Ecology_1  ...  \
# count    9985.000000  9985.000000  9985.000000  9985.000000  9985.000000  ...
# mean        7.063295     8.212719     7.524787  1957.871708     0.052043  ...
# std         4.957330     7.794345     8.170877    40.710758     0.042695  ...
# min         1.000000     2.000000     1.000000  1909.000000     0.000000  ...
# 25%         1.000000     2.000000     1.000000  1909.000000     0.000000  ...
# 50%         9.000000     6.000000     5.000000  1977.000000     0.075779  ...
# 75%        12.000000     6.000000     5.000000  1977.000000     0.075779  ...
# max        12.000000    22.000000    22.000000  2017.000000     0.101872  ...
#
#        Helthcare_2      Shops_1  Ecology_2_A  Ecology_2_B  Ecology_3_A  \
# count  9985.000000  9985.000000       9985.0       9985.0       9985.0
# mean      2.615724     3.361042          0.0          1.0          0.0
# std       2.211307     1.390265          0.0          0.0          0.0
# min       0.000000     0.000000          0.0          1.0          0.0
# 25%       0.000000     2.000000          0.0          1.0          0.0
# 50%       3.000000     3.000000          0.0          1.0          0.0
# 75%       5.000000     5.000000          0.0          1.0          0.0
# max       5.000000     5.000000          0.0          1.0          0.0
#
#        Ecology_3_B    Shops_2_A    Shops_2_B  Dist_mean_year  New_House
# count       9985.0  9985.000000  9985.000000     9985.000000     9985.0
# mean           1.0     0.015223     0.984777     1967.065198        0.0
# std            0.0     0.122444     0.122444       23.995631        0.0
# min            1.0     0.000000     0.000000     1937.000000        0.0
# 25%            1.0     0.000000     1.000000     1937.000000        0.0
# 50%            1.0     0.000000     1.000000     1986.000000        0.0
# 75%            1.0     0.000000     1.000000     1986.000000        0.0
# max            1.0     1.000000     1.000000     1993.000000        0.0
#
# [8 rows x 23 columns]

# %%
test.loc[test.LifeSquare>200]
# Out:
#         Id  DistrictId  Rooms     Square  LifeSquare  KitchenSquare  Floor  \
# 410  11533          94    2.0  48.713443  303.071094            6.0      5
#
#      HouseFloor  HouseYear  Ecology_1  ...  Helthcare_2  Shops_1  Ecology_2_A  \
# 410        12.0       1974   0.521867  ...            0        0            0
#
#      Ecology_2_B  Ecology_3_A  Ecology_3_B  Shops_2_A  Shops_2_B  \
# 410            1            0            1          0          1
#
#      Dist_mean_year  New_House
# 410            1982          0
#
# [1 rows x 23 columns]

# %%
test.loc[(test.LifeSquare - test.Square > 5)]
# Out:
#          Id  DistrictId  Rooms     Square  LifeSquare  KitchenSquare  Floor  \
# 410   11533          94    2.0  48.713443  303.071094            6.0      5
# 4713    170           6    2.0   2.900586   61.468563            1.0     18
#
#       HouseFloor  HouseYear  Ecology_1  ...  Helthcare_2  Shops_1  \
# 410         12.0       1974   0.521867  ...            0        0
# 4713        17.0       2014   0.243205  ...            0        0
#
#       Ecology_2_A  Ecology_2_B  Ecology_3_A  Ecology_3_B  Shops_2_A  \
# 410             0            1            0            1          0
# 4713            0            1            0            1          0
#
#       Shops_2_B  Dist_mean_year  New_House
# 410           1            1982          0
# 4713          1            1991          0
#
# [2 rows x 23 columns]

# %%
test.loc[[410],'LifeSquare']=30.307
test.loc[[4713],'Square']=61.468

# %%
test.loc[(test.Square<13)]
# Out:
#          Id  DistrictId  Rooms    Square  LifeSquare  KitchenSquare  Floor  \
# 66     9011          53    1.0  1.378543    1.353573            1.0      1
# 608   16401          30    1.0  2.645046    4.338755            1.0      2
# 837    2138          27    1.0  5.647458    1.501582            1.0      1
# 1165  10120           6    1.0  5.100672    3.861780            1.0      3
# 4490   1165          27    1.0  2.372101    1.899119            1.0      2
# 4540   7855           6    1.0  4.967143    2.968086            1.0      3
# 4902   1420          45    1.0  1.975769    2.900371            1.0      1
#
#       HouseFloor  HouseYear  Ecology_1  ...  Helthcare_2  Shops_1  \
# 66           1.0       1977   0.049637  ...            1        3
# 608          1.0       1977   0.000078  ...            3       23
# 837          1.0       1977   0.017647  ...            0        0
# 1165         1.0       1977   0.243205  ...            0        0
# 4490        17.0       1977   0.011654  ...            0        0
# 4540         1.0       2018   0.243205  ...            0        0
# 4902         1.0       1977   0.195781  ...            3        2
#
#       Ecology_2_A  Ecology_2_B  Ecology_3_A  Ecology_3_B  Shops_2_A  \
# 66              0            1            0            1          0
# 608             0            1            0            1          0
# 837             0            1            0            1          0
# 1165            0            1            0            1          0
# 4490            0            1            0            1          0
# 4540            0            1            0            1          0
# 4902            0            1            0            1          0
#
#       Shops_2_B  Dist_mean_year  New_House
# 66            1            1991          0
# 608           1            1990          0
# 837           1            1993          0
# 1165          1            1991          0
# 4490          1            1993          0
# 4540          1            1991          1
# 4902          1            1992          0
#
# [7 rows x 23 columns]

# %%
test.loc[[66],'Square'] = 13.785
test.loc[[608],'Square'] = 26.450
test.loc[[4490],'Square'] = 23.721
test.loc[[4490],'Square'] = 49.671
test.loc[[4902],'Square'] = 19.757

# %%
test.loc[(test.Square < 13), 'Square'] = 13

# %% [markdown]
# <H3>Этажность</H3>

# %% [markdown]
# Исправление ошибок

# %%
test.loc[test.Floor > test.HouseFloor,'HouseFloor'] = test.loc[test.Floor > test.HouseFloor,'Floor']

# %% [markdown]
# Новый признак: первый и последний этаж

# %%
test['frs_lst_floor'] = (test['Floor'] == test['HouseFloor']) | (test['Floor'] <= 1)
test['frs_lst_floor'] = test['frs_lst_floor'].astype('int')

# %% [markdown]
# Проверка

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5000 entries, 0 to 4999
# Data columns (total 24 columns):
# Id                5000 non-null int64
# DistrictId        5000 non-null int64
# Rooms             5000 non-null float64
# Square            5000 non-null float64
# LifeSquare        3959 non-null float64
# KitchenSquare     5000 non-null float64
# Floor             5000 non-null int64
# HouseFloor        5000 non-null float64
# HouseYear         5000 non-null int64
# Ecology_1         5000 non-null float64
# Social_1          5000 non-null int64
# Social_2          5000 non-null int64
# Social_3          5000 non-null int64
# Helthcare_2       5000 non-null int64
# Shops_1           5000 non-null int64
# Ecology_2_A       5000 non-null uint8
# Ecology_2_B       5000 non-null uint8
# Ecology_3_A       5000 non-null uint8
# Ecology_3_B       5000 non-null uint8
# Shops_2_A         5000 non-null uint8
# Shops_2_B         5000 non-null uint8
# Dist_mean_year    5000 non-null int32
# New_House         5000 non-null int32
# frs_lst_floor     5000 non-null int32
# dtypes: float64(6), int32(3), int64(9), uint8(6)
# memory usage: 872.9 KB

# %% [markdown]
# <H2>Предсказание цены</H2>

# %%
price_pred = model.predict(test[features])

# %%
test['Price'] = price_pred

# %%
test[['Id', 'Price']].to_csv('YChizhevskiy_predictions.csv', index = None)
